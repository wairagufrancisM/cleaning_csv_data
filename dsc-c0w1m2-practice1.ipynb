# %% [markdown]
# # Practice Lab for Types of Data

# %% [markdown]
# You are given a record of dogs that have visited a small vet clinic in the past few hours. The clinic is currently very busy. There is a new virus that turns some dogs (who are usually by default all good boys and girls) into bad doggies. Also a very nasty doggy flu has been going around at the same time.
#
# * Given the situation, data entry has been rushed and there are some inconsistencies that need to be addressed and type conversion you will need to do to get the data into your organization's standard.
# * Your direct manager (who is not a data person) is European and wants the dog length to be converted to metric because he thinks that the inch is a preposterous unit of measurement.
# * The head veterinarian wants a flagging system for dogs that come in running a fever.
#
#
# You, the only data analyst at this small clinic, have been assigned these tasks. Exercise your knowledge of string cleaning, mathematical operations on numeric quantities, and booleans in order to complete the work.

# %%
# load data given to you
dog_data = [['Name', 'Breed', 'Good Doggy?', 'Length [in]', 'Weight Range', 'Body Temp [F]'],
    ["Buddy", "Golden Retriever", "Good", 24, 'Overweight', 101.5],
    ["Cooper", "Doberman Pinscher", "Bad", 28, 'Normal',  105.2],
    ["Max", "GERMAN Shepherd", "Good", 26, 'Normal', 100.2],
    ["Bella", "Chow Chow", "Bad", 20, 'Normal', 100.5],
    ["Lucy", " Yorkshire Terrier", "Good", 9, 'Normal', 102.0],
    ["Charlie", "Beagle", "Good", 13, 'Overweight', 100.4],
    ["Daisy", "Akita", "Bad", 24, 'Normal',99.8],
    ["Bailey", "JACK russell terrier", "Bad", 10, 'Underweight', 101.2],
    ["Lola", "Rottweiler   ", "Good", 27, 'Normal', 102.5],
    ["Sadie", "Siberian_Husky", "Bad", 23, 'Normal', 99.5],
    ["Penny", "STANDARD Poodle", "Good", 18, 'Underweight', 100.7],
    ["Bruno", "Bulldog", "Bad", 14, 'Normal', 104.1],
    ["Rosie", "Beagle", "Good", 13, 'Normal', 100.6],
    ["Duke", "    DOBERMAN PINSCHER", "Good", 28,  'Normal',100.1],
    ["Luna", "Shiba Inu", "Good", 17, 'Obese',  100.3],
    ["Scout", "Golden_Retriever", "Good", 22, 'Normal', 103.5],
    ["Rex", "Rottweiler", "Bad", 23, 'Normal', 100.2],
]

# %% [markdown]
# ### Instructions

# %% [markdown]
# 1. Write a clean_string function that takes in a string and removes leading/trailing spaces, replaces underscores with spaces, and capitalizes the first letter of each word. Use this function to replace the values in the 'Breed' column with the new cleaned values.

# %%
for breed in dog_data:
    if dog_data.index(breed) > 0:
        breed[1] = breed[1].strip().replace("_", "").capitalize()

dog_data
# Out:
# [['Name',
#   'Breed',
#   'Good Doggy?',
#   'Length [in]',
#   'Weight Range',
#   'Body Temp [F]'],
#  ['Buddy', 'Golden retriever', 'Good', 24, 'Overweight', 101.5],
#  ['Cooper', 'Doberman pinscher', 'Bad', 28, 'Normal', 105.2],
#  ['Max', 'German shepherd', 'Good', 26, 'Normal', 100.2],
#  ['Bella', 'Chow chow', 'Bad', 20, 'Normal', 100.5],
#  ['Lucy', 'Yorkshire terrier', 'Good', 9, 'Normal', 102.0],
#  ['Charlie', 'Beagle', 'Good', 13, 'Overweight', 100.4],
#  ['Daisy', 'Akita', 'Bad', 24, 'Normal', 99.8],
#  ['Bailey', 'Jack russell terrier', 'Bad', 10, 'Underweight', 101.2],
#  ['Lola', 'Rottweiler', 'Good', 27, 'Normal', 102.5],
#  ['Sadie', 'Siberianhusky', 'Bad', 23, 'Normal', 99.5],
#  ['Penny', 'Standard poodle', 'Good', 18, 'Underweight', 100.7],
#  ['Bruno', 'Bulldog', 'Bad', 14, 'Normal', 104.1],
#  ['Rosie', 'Beagle', 'Good', 13, 'Normal', 100.6],
#  ['Duke', 'Doberman pinscher', 'Good', 28, 'Normal', 100.1],
#  ['Luna', 'Shiba inu', 'Good', 17, 'Obese', 100.3],
#  ['Scout', 'Goldenretriever', 'Good', 22, 'Normal', 103.5],
#  ['Rex', 'Rottweiler', 'Bad', 23, 'Normal', 100.2]]

# %% [markdown]
# 2. Transform lengths from inches to centimeters.

# %%
for dog in dog_data:
    if dog_data.index(dog) > 0:
        dog[3] = dog[3] * 2.5
dog_data
# Out:
# [['Name',
#   'Breed',
#   'Good Doggy?',
#   'Length [in]',
#   'Weight Range',
#   'Body Temp [F]'],
#  ['Buddy', 'Golden retriever', 'Good', 60.0, 'Overweight', 101.5],
#  ['Cooper', 'Doberman pinscher', 'Bad', 70.0, 'Normal', 105.2],
#  ['Max', 'German shepherd', 'Good', 65.0, 'Normal', 100.2],
#  ['Bella', 'Chow chow', 'Bad', 50.0, 'Normal', 100.5],
#  ['Lucy', 'Yorkshire terrier', 'Good', 22.5, 'Normal', 102.0],
#  ['Charlie', 'Beagle', 'Good', 32.5, 'Overweight', 100.4],
#  ['Daisy', 'Akita', 'Bad', 60.0, 'Normal', 99.8],
#  ['Bailey', 'Jack russell terrier', 'Bad', 25.0, 'Underweight', 101.2],
#  ['Lola', 'Rottweiler', 'Good', 67.5, 'Normal', 102.5],
#  ['Sadie', 'Siberianhusky', 'Bad', 57.5, 'Normal', 99.5],
#  ['Penny', 'Standard poodle', 'Good', 45.0, 'Underweight', 100.7],
#  ['Bruno', 'Bulldog', 'Bad', 35.0, 'Normal', 104.1],
#  ['Rosie', 'Beagle', 'Good', 32.5, 'Normal', 100.6],
#  ['Duke', 'Doberman pinscher', 'Good', 70.0, 'Normal', 100.1],
#  ['Luna', 'Shiba inu', 'Good', 42.5, 'Obese', 100.3],
#  ['Scout', 'Goldenretriever', 'Good', 55.0, 'Normal', 103.5],
#  ['Rex', 'Rottweiler', 'Bad', 57.5, 'Normal', 100.2]]

# %% [markdown]
# 3. Convert Good/Bad doggy column to boolean

# %%
for index, dog in enumerate(dog_data):
    if index > 0:
        if dog[2] == "Good":
            dog[2] = True
        elif dog[2] == "Bad":
            dog[2] = False    
dog_data
# Out:
# [['Name',
#   'Breed',
#   'Good Doggy?',
#   'Length [in]',
#   'Weight Range',
#   'Body Temp [F]'],
#  ['Buddy', 'Golden retriever', True, 60.0, 'Overweight', 101.5],
#  ['Cooper', 'Doberman pinscher', False, 70.0, 'Normal', 105.2],
#  ['Max', 'German shepherd', True, 65.0, 'Normal', 100.2],
#  ['Bella', 'Chow chow', False, 50.0, 'Normal', 100.5],
#  ['Lucy', 'Yorkshire terrier', True, 22.5, 'Normal', 102.0],
#  ['Charlie', 'Beagle', True, 32.5, 'Overweight', 100.4],
#  ['Daisy', 'Akita', False, 60.0, 'Normal', 99.8],
#  ['Bailey', 'Jack russell terrier', False, 25.0, 'Underweight', 101.2],
#  ['Lola', 'Rottweiler', True, 67.5, 'Normal', 102.5],
#  ['Sadie', 'Siberianhusky', False, 57.5, 'Normal', 99.5],
#  ['Penny', 'Standard poodle', True, 45.0, 'Underweight', 100.7],
#  ['Bruno', 'Bulldog', False, 35.0, 'Normal', 104.1],
#  ['Rosie', 'Beagle', True, 32.5, 'Normal', 100.6],
#  ['Duke', 'Doberman pinscher', True, 70.0, 'Normal', 100.1],
#  ['Luna', 'Shiba inu', True, 42.5, 'Obese', 100.3],
#  ['Scout', 'Goldenretriever', True, 55.0, 'Normal', 103.5],
#  ['Rex', 'Rottweiler', False, 57.5, 'Normal', 100.2]]

# %% [markdown]
# 4. Convert the ‘Weight’ column to an integer representation.

# %%
# lst = set()
weight_mapper = {"Underweight": 0, "Normal": 1, "Overweight": 2, "Obese": 3}

for i, dog in enumerate(dog_data):
    if i > 0:
        dog[4] = weight_mapper[dog[4]]
dog_data
# Out:
# [['Name',
#   'Breed',
#   'Good Doggy?',
#   'Length [in]',
#   'Weight Range',
#   'Body Temp [F]'],
#  ['Buddy', 'Golden retriever', True, 60.0, 2, 101.5],
#  ['Cooper', 'Doberman pinscher', False, 70.0, 1, 105.2],
#  ['Max', 'German shepherd', True, 65.0, 1, 100.2],
#  ['Bella', 'Chow chow', False, 50.0, 1, 100.5],
#  ['Lucy', 'Yorkshire terrier', True, 22.5, 1, 102.0],
#  ['Charlie', 'Beagle', True, 32.5, 2, 100.4],
#  ['Daisy', 'Akita', False, 60.0, 1, 99.8],
#  ['Bailey', 'Jack russell terrier', False, 25.0, 0, 101.2],
#  ['Lola', 'Rottweiler', True, 67.5, 1, 102.5],
#  ['Sadie', 'Siberianhusky', False, 57.5, 1, 99.5],
#  ['Penny', 'Standard poodle', True, 45.0, 0, 100.7],
#  ['Bruno', 'Bulldog', False, 35.0, 1, 104.1],
#  ['Rosie', 'Beagle', True, 32.5, 1, 100.6],
#  ['Duke', 'Doberman pinscher', True, 70.0, 1, 100.1],
#  ['Luna', 'Shiba inu', True, 42.5, 3, 100.3],
#  ['Scout', 'Goldenretriever', True, 55.0, 1, 103.5],
#  ['Rex', 'Rottweiler', False, 57.5, 1, 100.2]]

# %% [markdown]
# 5. Create a new column called Has_Fever. The value should yield 0 if a dog has normal body temperature and 1 if a dog is running a fever. A dog should be flagged as having a fever if their body temperature is above 102 F.

# %%
for index, dog in enumerate(dog_data):
    if index == 0:
        dog.append("Has_Fever")
    else:
        dog.append(dog[5] > 102)
# Out:
# [['Name',
#   'Breed',
#   'Good Doggy?',
#   'Length [in]',
#   'Weight Range',
#   'Body Temp [F]',
#   'Has_Fever'],
#  ['Buddy', 'Golden retriever', True, 60.0, 2, 101.5, False],
#  ['Cooper', 'Doberman pinscher', False, 70.0, 1, 105.2, True],
#  ['Max', 'German shepherd', True, 65.0, 1, 100.2, False],
#  ['Bella', 'Chow chow', False, 50.0, 1, 100.5, False],
#  ['Lucy', 'Yorkshire terrier', True, 22.5, 1, 102.0, False],
#  ['Charlie', 'Beagle', True, 32.5, 2, 100.4, False],
#  ['Daisy', 'Akita', False, 60.0, 1, 99.8, False],
#  ['Bailey', 'Jack russell terrier', False, 25.0, 0, 101.2, False],
#  ['Lola', 'Rottweiler', True, 67.5, 1, 102.5, True],
#  ['Sadie', 'Siberianhusky', False, 57.5, 1, 99.5, False],
#  ['Penny', 'Standard poodle', True, 45.0, 0, 100.7, False],
#  ['Bruno', 'Bulldog', False, 35.0, 1, 104.1, True],
#  ['Rosie', 'Beagle', True, 32.5, 1, 100.6, False],
#  ['Duke', 'Doberman pinscher', True, 70.0, 1, 100.1, False],
#  ['Luna', 'Shiba inu', True, 42.5, 3, 100.3, False],
#  ['Scout', 'Goldenretriever', True, 55.0, 1, 103.5, True],
#  ['Rex', 'Rottweiler', False, 57.5, 1, 100.2, False]]

# %% [markdown]
# 6. Run cell to display all changes you have made.

# %%
dog_data
# Out:
# [['Name',
#   'Breed',
#   'Good Doggy?',
#   'Length [in]',
#   'Weight Range',
#   'Body Temp [F]',
#   'Has_Fever'],
#  ['Buddy', 'Golden retriever', True, 60.0, 2, 101.5, False],
#  ['Cooper', 'Doberman pinscher', False, 70.0, 1, 105.2, True],
#  ['Max', 'German shepherd', True, 65.0, 1, 100.2, False],
#  ['Bella', 'Chow chow', False, 50.0, 1, 100.5, False],
#  ['Lucy', 'Yorkshire terrier', True, 22.5, 1, 102.0, False],
#  ['Charlie', 'Beagle', True, 32.5, 2, 100.4, False],
#  ['Daisy', 'Akita', False, 60.0, 1, 99.8, False],
#  ['Bailey', 'Jack russell terrier', False, 25.0, 0, 101.2, False],
#  ['Lola', 'Rottweiler', True, 67.5, 1, 102.5, True],
#  ['Sadie', 'Siberianhusky', False, 57.5, 1, 99.5, False],
#  ['Penny', 'Standard poodle', True, 45.0, 0, 100.7, False],
#  ['Bruno', 'Bulldog', False, 35.0, 1, 104.1, True],
#  ['Rosie', 'Beagle', True, 32.5, 1, 100.6, False],
#  ['Duke', 'Doberman pinscher', True, 70.0, 1, 100.1, False],
#  ['Luna', 'Shiba inu', True, 42.5, 3, 100.3, False],
#  ['Scout', 'Goldenretriever', True, 55.0, 1, 103.5, True],
#  ['Rex', 'Rottweiler', False, 57.5, 1, 100.2, False]]
